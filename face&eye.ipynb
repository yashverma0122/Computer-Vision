# %%
import numpy as np
import cv2
 
face_classifier = cv2.CascadeClassifier('Haarcascades/haarcascade_frontalface_default.xml')
eye_classifier = cv2.CascadeClassifier('Haarcascades/lena.jpg')
 
img = cv2.imread('image_examples/lena.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

faces = face_classifier.detectMultiScale(gray, 1.3, 5)

# When no faces detected, face_classifier returns and empty tuple
if faces == ():
    print("No Face Found")

for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(127,0,255),2)
    cv2.imshow('img',img)
    cv2.waitKey(0)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_classifier.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(255,255,0),2)
        cv2.imshow('img',img)
        cv2.waitKey(0)

# cv2.findcontours()
cv2.destroyAllWindows()
# Out:
# [ERROR:0@0.021] global persistence.cpp:505 open Can't open file: 'Haarcascades/lena.jpg' in read mode
# /tmp/ipykernel_6886/3102957848.py:13: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   if faces == ():
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
#
# QObject::moveToThread: Current thread (0x298fed0) is not the object's thread (0x2cb3400).
# Cannot move to target thread (0x298fed0)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipykernel_6886/3102957848.py in <module>
#      20     roi_gray = gray[y:y+h, x:x+w]
#      21     roi_color = img[y:y+h, x:x+w]
# ---> 22     eyes = eye_classifier.detectMultiScale(roi_gray)
#      23     for (ex,ey,ew,eh) in eyes:
#      24         cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(255,255,0),2)
#
# error: OpenCV(4.7.0) /io/opencv/modules/objdetect/src/cascadedetect.cpp:1689: error: (-215:Assertion failed) !empty() in function 'detectMultiScale'
